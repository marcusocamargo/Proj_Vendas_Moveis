# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
#
# ## <font color='blue'>Fundamentos de Linguagem Python Para Análise de Dados e Data Science</font>
#
# ## <font color='blue'>Projeto 2</font>
#
# ## <font color='blue'>Análise Exploratória de Dados em Linguagem Python Para a Área de Varejo</font>

# %% [markdown]
# ![DSA](imagens/projeto2.png)

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.13

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# ## Carregando os Dados

# %%
# Carrega o dataset
df_dsa = pd.read_csv('dados/dataset.csv')

# %%
# Shape
df_dsa.shape
# Out:
# (9700, 11)

# %%
# Amostra dos dados
df_dsa.head(10)
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 5  CA-2015-115812  09/06/2015   BH-11710   Consumer  United States
# 6  CA-2015-115812  09/06/2015   BH-11710   Consumer  United States
# 7  CA-2015-115812  09/06/2015   BH-11710   Consumer  United States
# 8  CA-2015-115812  09/06/2015   BH-11710   Consumer  United States
# 9  CA-2015-115812  09/06/2015   BH-11710   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
# Amostra dos dados
df_dsa.tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9695  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9696  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9697  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9698  CA-2017-105291  30/10/2017   SP-20920     Consumer  United States
# 9699  CA-2018-147032  31/07/2018   LB-16795  Home Office  United States
#
#                Cidade      Estado       ID_Produto        Categoria  \
# 9695        Inglewood  California  OFF-PA-10004569  Office Supplies
# 9696        Inglewood  California  OFF-AP-10000027  Office Supplies
# 9697        Inglewood  California  TEC-PH-10000675       Technology
# 9698  San Luis Obispo  California  OFF-FA-10003059  Office Supplies
# 9699       Wilmington    Delaware  OFF-PA-10003256  Office Supplies
#
#      SubCategoria  Valor_Venda
# 9695        Paper       22.830
# 9696   Appliances       54.320
# ...

# %% [markdown]
# ## Análise Exploratória

# %%
# Colunas do conjunto de dados
df_dsa.columns
# Out:
# Index(['ID_Pedido', 'Data_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Cidade',
#        'Estado', 'ID_Produto', 'Categoria', 'SubCategoria', 'Valor_Venda'],
#       dtype='object')

# %%
df_dsa.sort_values(by='Valor_Venda', ascending=False)
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 2697  CA-2015-145317  18/03/2015   SM-20320  Home Office  United States
# 6823  CA-2017-118689  02/10/2017   TC-20980    Corporate  United States
# 8150  CA-2018-140151  23/03/2018   RB-19360     Consumer  United States
# 2623  CA-2018-127180  22/10/2018   TA-21385  Home Office  United States
# 4187  CA-2018-166709  17/11/2018   HL-15040     Consumer  United States
# ...              ...         ...        ...          ...            ...
# 2106  US-2015-152723  26/09/2015   HG-14965    Corporate  United States
# 4708  CA-2015-112403  31/03/2015   JO-15280     Consumer  United States
# 8655  CA-2017-168361  21/06/2017   KB-16600    Corporate  United States
# 9289  CA-2018-124114  02/03/2018   RS-19765    Corporate  United States
# 4098  US-2018-102288  19/06/2018   ZC-21910     Consumer  United States
#
#              Cidade        Estado       ID_Produto        Categoria  \
# ...

# %%
sup = df_dsa[(df_dsa.Categoria == 'Office Supplies') & (df_dsa.Valor_Venda)]
sup.sort_values(by='Valor_Venda', ascending=False)
# Out:
#            ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 9036  CA-2017-117121  17/12/2017   AB-10105   Consumer  United States
# 4095  CA-2015-116904  23/09/2015   SC-20095   Consumer  United States
# 2505  CA-2015-143917  25/07/2015   KL-16645   Consumer  United States
# 509   CA-2016-145352  16/03/2016   CM-12385   Consumer  United States
# 6517  CA-2018-138289  16/01/2018   AR-10540   Consumer  United States
# ...              ...         ...        ...        ...            ...
# 2106  US-2015-152723  26/09/2015   HG-14965  Corporate  United States
# 4708  CA-2015-112403  31/03/2015   JO-15280   Consumer  United States
# 8655  CA-2017-168361  21/06/2017   KB-16600  Corporate  United States
# 9289  CA-2018-124114  02/03/2018   RS-19765  Corporate  United States
# 4098  US-2018-102288  19/06/2018   ZC-21910   Consumer  United States
#
#              Cidade        Estado       ID_Produto        Categoria  \
# ...

# %%
# Verificando o tipo de dado de cada coluna
df_dsa.dtypes
# Out:
# ID_Pedido        object
# Data_Pedido      object
# ID_Cliente       object
# Segmento         object
# Pais             object
# Cidade           object
# Estado           object
# ID_Produto       object
# Categoria        object
# SubCategoria     object
# Valor_Venda     float64
# dtype: object

# %%
# Resumo estatístico da coluna com o valor de venda
df_dsa['Valor_Venda'].describe()
# Out:
# count     9700.000000
# mean       230.469892
# std        627.504252
# min          0.444000
# 25%         17.248000
# 50%         54.272000
# 75%        209.932500
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
# Verificando se há registros duplicados
df_dsa[df_dsa.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID_Pedido, Data_Pedido, ID_Cliente, Segmento, Pais, Cidade, Estado, ID_Produto, Categoria, SubCategoria, Valor_Venda]
# Index: []

# %%
# Verificando de há valores ausentes
df_dsa.isnull().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Cidade          0
# Estado          0
# ID_Produto      0
# Categoria       0
# SubCategoria    0
# Valor_Venda     0
# dtype: int64

# %%
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %% [markdown]
# ## Pergunta de Negócio 1:
#
# ### Qual Cidade com Maior Valor de Venda de Produtos da Categoria 'Office Supplies'?

# %%
sup = df_dsa[(df_dsa.Categoria == 'Office Supplies')]

# %%
df_dsa_p1_total = sup.groupby('Cidade')['Valor_Venda'].sum()

# %%
cidade_maior_venda = df_dsa_p1_total.idxmax()
print(cidade_maior_venda)
# Out:
# New York City

# %% [markdown]
# ## Pergunta de Negócio 2:
#
# ### Qual o Total de Vendas Por Data do Pedido?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
data_sum = df_dsa.groupby('Data_Pedido')['Valor_Venda'].sum()
data_sum.head()
# Out:
# Data_Pedido
# 01/01/2018    1481.8280
# 01/02/2015     468.9000
# 01/02/2017     161.9700
# 01/03/2015    2203.1510
# 01/03/2016    1642.1744
# Name: Valor_Venda, dtype: float64

# %%
plt.figure(figsize=(20,6))
data_sum.plot(x= 'Data_Pedido', y= 'Valor_Venda')
plt.title('TOTAL DE VENDAS POR DATA DO PEDIDO')
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 3:
#
# ### Qual o Total de Vendas por Estado?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
data_estado = df_dsa.groupby('Estado')['Valor_Venda'].sum().reset_index()
data_estado
# Out:
#                   Estado  Valor_Venda
# 0                Alabama   19510.6400
# 1                Arizona   35272.6570
# 2               Arkansas   11673.8300
# 3             California  442927.0975
# 4               Colorado   31841.5980
# 5            Connecticut   13366.7370
# 6               Delaware   26452.5890
# 7   District of Columbia    2865.0200
# 8                Florida   88043.7000
# 9                Georgia   48083.1600
# 10                 Idaho    4292.5160
# 11              Illinois   78109.9270
# 12               Indiana   48718.4000
# 13                  Iowa    4443.5600
# 14                Kansas    2914.3100
# 15              Kentucky   36409.5800
# 16             Louisiana    9131.0500
# 17                 Maine    1270.5300
# 18              Maryland   23705.5230
# 19         Massachusetts   27363.2640
# 20              Michigan   76081.1740
# 21             Minnesota   29863.1500
# 22           Mississippi   10771.3400
# 23              Missouri   22205.1500
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(data = data_estado, 
            y = 'Valor_Venda', 
            x = 'Estado').set(title = 'Vendas Por Estado')
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 4:
#
# ### Quais São as 10 Cidades com Maior Total de Vendas?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
top_dez1 = df_dsa.groupby('Cidade')['Valor_Venda'].sum()
top_dez2 = top_dez1.sort_values(ascending=False).head(10).reset_index()
top_dez2
# Out:
#           Cidade  Valor_Venda
# 0  New York City  251749.2190
# 1    Los Angeles  171654.6330
# 2        Seattle  114725.4780
# 3  San Francisco  107489.9520
# 4   Philadelphia  107197.8030
# 5        Houston   61590.1868
# 6      San Diego   47458.3790
# 7        Chicago   46974.3430
# 8   Jacksonville   44713.1830
# 9        Detroit   42446.9440

# %%
plt.figure(figsize=(10,6))
sns.barplot(data = top_dez2, 
            y = 'Valor_Venda', 
            x = 'Cidade').set(title = 'Top 10 Cidades')
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 5:
#
# ### Qual Segmento Teve o Maior Total de Vendas?
#
# Demonstre o resultado através de um gráfico de pizza.

# %%
maior_seg = df_dsa.groupby('Segmento')['Valor_Venda'].sum().reset_index().sort_values(by='Valor_Venda', ascending= False)
maior_seg
# Out:
#       Segmento   Valor_Venda
# 0     Consumer  1.133834e+06
# 1    Corporate  6.792322e+05
# 2  Home Office  4.224914e+05

# %%
# Função para converter os dados em valor absoluto
def autopct_format(values): 
    def my_format(pct): 
        total = sum(values) 
        val = int(round(pct * total / 100.0))
        return ' $ {v:d}'.format(v = val)
    return my_format

# %%
# Plot

# Tamanho da figura
plt.figure(figsize = (16, 6))

# Gráfico de pizza
plt.pie(maior_seg['Valor_Venda'], 
        labels = maior_seg['Segmento'],
        autopct = autopct_format(maior_seg['Valor_Venda']),
        startangle = 90)

# Limpa o círculo central
centre_circle = plt.Circle((0, 0), 0.82, fc = 'white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Labels e anotações
plt.annotate(text = 'Total de Vendas: ' + '$ ' + str(int(sum(maior_seg['Valor_Venda']))), xy = (-0.25, 0))
plt.title('Total de Vendas Por Segmento')
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 6 (Desafio Nível Baby):
#
# ### Qual o Total de Vendas Por Segmento e Por Ano?

# %%
# Convertemos a coluna de data para o tipo datetime para obter o formato adequado
df_dsa['Data_Pedido'] = pd.to_datetime(df_dsa['Data_Pedido'], dayfirst = True)

# %%
df_dsa.dtypes
# Out:
# ID_Pedido               object
# Data_Pedido     datetime64[ns]
# ID_Cliente              object
# Segmento                object
# Pais                    object
# Cidade                  object
# Estado                  object
# ID_Produto              object
# Categoria               object
# SubCategoria            object
# Valor_Venda            float64
# dtype: object

# %%
# Extraímos o ano criando nova variável
df_dsa['Ano'] = df_dsa['Data_Pedido'].dt.year
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano
# 0     261.9600  2017
# 1     731.9400  2017
# 2      14.6200  2017
# ...

# %%
data_ano = df_dsa.groupby(['Ano', 'Segmento'])['Valor_Venda'].sum().reset_index()
data_ano
# Out:
#      Ano     Segmento  Valor_Venda
# 0   2015     Consumer  256719.9166
# 1   2015    Corporate  125819.5957
# 2   2015  Home Office   88229.0878
# 3   2016     Consumer  265295.2593
# 4   2016    Corporate  114643.1229
# 5   2016  Home Office   74134.1332
# 6   2017     Consumer  288459.5572
# 7   2017    Corporate  203266.7398
# 8   2017  Home Office  103639.6270
# 9   2018     Consumer  323359.6019
# 10  2018    Corporate  235502.7284
# 11  2018  Home Office  156488.5849

# %% [markdown]
# ## Pergunta de Negócio 7 (Desafio Nível Júnior):
#
# Os gestores da empresa estão considerando conceder diferentes faixas de descontos e gostariam de fazer uma simulação com base na regra abaixo:
#
# - Se o Valor_Venda for maior que 1000 recebe 15% de desconto.
# - Se o Valor_Venda for menor que 1000 recebe 10% de desconto.
#
# ### Quantas Vendas Receberiam 15% de Desconto?

# %%
#Descobrindo valor de venda maior que 1000
# Cria uma nova coluna de acordo com a regra definida acima
df_dsa['Desconto'] = np.where(df_dsa['Valor_Venda'] > 1000, 0.15, 0.10)
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto
# 0     261.9600  2017       0.1
# ...

# %%
# Total por cada valor da variável
df_dsa['Desconto'].value_counts()
# Out:
# 0.10    9243
# 0.15     457
# Name: Desconto, dtype: int64

# %% [markdown]
# ## Pergunta de Negócio 8 (Desafio Nível Master):
#
# ### Considere Que a Empresa Decida Conceder o Desconto de 15% do Item Anterior. Qual Seria a Média do Valor de Venda Antes e Depois do Desconto?

# %%
# Criamos uma coluna calculando o valor de venda menos o desconto
df_dsa['Valor_Venda_Desconto'] = df_dsa['Valor_Venda'] - (df_dsa['Valor_Venda'] * df_dsa['Desconto'])
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto  Valor_Venda_Desconto
# ...

# %%
# Filtrando as vendas antes do desconto de 15%
df_dsa_p8_vendas_antes_desconto = df_dsa.loc[df_dsa['Desconto'] == 0.15, 'Valor_Venda']
print(round(df_dsa_p8_vendas_antes_desconto.mean(), 2))
# Out:
# 2116.81

# %%
# Filtrando as vendas depois do desconto de 15%
df_dsa_p8_vendas_depois_desconto = df_dsa.loc[df_dsa['Desconto'] == 0.15, 'Valor_Venda_Desconto']
print(round(df_dsa_p8_vendas_depois_desconto.mean(), 2))
# Out:
# 1799.29

# %% [markdown]
# ## Pergunta de Negócio 9 (Desafio Nível Master Ninja):
#
# ### Qual o Média de Vendas Por Segmento, Por Ano e Por Mês?
#
# Demonstre o resultado através de gráfico de linha.

# %% [markdown]
# ## Pergunta de Negócio 10 (Desafio Nível Master Ninja das Galáxias):
#
# ### Qual o Total de Vendas Por Categoria e SubCategoria, Considerando Somente as Top 12 SubCategorias?
#
# Demonstre tudo através de um único gráfico.

# %% [markdown]
# # Fim
